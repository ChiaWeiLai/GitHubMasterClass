# %%
import cot_reports as cot

# %%
df = cot.cot_hist(cot_report_type= 'traders_in_financial_futures_futopt')
# Out:
# Selected: COT Traders in Financial Futures report. Futures and Options.
# Stored the extracted file C_TFF_2006_2016.txt in the working directory.

# %%
df = cot.cot_year(year = 2009, cot_report_type = 'traders_in_financial_futures_fut')
# Out:
# Selected: traders_in_financial_futures_fut
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /var/folders/l2/g62nwg6n517g5516gcjv7mh80000gn/T/ipykernel_11042/2988507984.py in <module>
# ----> 1 df = cot.cot_year(year = 2009, cot_report_type = 'traders_in_financial_futures_fut')
#
# ~/anaconda3/lib/python3.8/site-packages/cot_reports/cot_reports.py in cot_year(year, cot_report_type)
#     149     cot_url = "https://cftc.gov/files/dea/history/" + rep + str(year) + ".zip"
#     150     r = requests.get(cot_url)
# --> 151     z = zipfile.ZipFile(io.BytesIO(r.content))
#     152     z.extractall()
#     153     df = pd.read_csv(txt, low_memory=False)
#
# ~/anaconda3/lib/python3.8/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# ...

# %%
df
# Out:
#                              Market_and_Exchange_Names  \
# 0       CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 1       CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 2       CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 3       CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 4       CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# ..                                                 ...
# 831  S&P GSCI COMMODITY INDEX - CHICAGO MERCANTILE ...
# 832  S&P GSCI COMMODITY INDEX - CHICAGO MERCANTILE ...
# 833  S&P GSCI COMMODITY INDEX - CHICAGO MERCANTILE ...
# 834  S&P GSCI COMMODITY INDEX - CHICAGO MERCANTILE ...
# 835  S&P GSCI COMMODITY INDEX - CHICAGO MERCANTILE ...
#
#      As_of_Date_In_Form_YYMMDD Report_Date_as_MM_DD_YYYY  \
# 0                       101228                2010-12-28
# 1                       101221                2010-12-21
# 2                       101214                2010-12-14
# 3                       101207                2010-12-07
# ...
